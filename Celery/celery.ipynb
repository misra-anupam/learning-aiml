# %% [markdown]
# Distributed task execution with broker and backend

# %% [markdown]
# Broker is between client and workers -> Mandatory
#
# Backend stores task status & return value -> Optional

# %% [markdown]
# Very imp.: https://stackoverflow.com/questions/9077687/why-use-celery-instead-of-rabbitmq
